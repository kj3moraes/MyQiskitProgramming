# %%
# %matplotlib inline
# Importing standard Qiskit libraries
from qiskit import QuantumCircuit, execute, Aer, IBMQ
from qiskit.compiler import transpile, assemble
from qiskit.visualization import *
from math import sqrt, pi

# Loading your IBM Q account(s)
provider = IBMQ.load_account()

# %% [markdown]
# ## Quick Exercise 1

# %% [markdown]
# ### Defining the Circuit

# %%
qc = QuantumCircuit(1,1)
qc.draw('mpl')

# %% [markdown]
# ### 1. Create a state vector that will give a 1/3 probability of measuring |0⟩.

# %%
initialState = [1/sqrt(3), sqrt(2/3)]
qc.initialize(initialState, 0)
qc.measure(0, 0)
qc.draw('mpl')

# %% [markdown]
# ### Simulating the Circuit

# %%
nativeSim = Aer.get_backend('qasm_simulator')
result = execute(qc, backend = nativeSim, shots = 1024).result()
plot_histogram(result.get_counts(qc))

# %% [markdown]
# ### 2. Create a different state vector that will give the same measurement probabilities.

# %%
qc = QuantumCircuit(1, 1) 
alternateState = [sqrt(3) / 3, 2 /sqrt(6)]
qc.initialize(alternateState, 0)
qc.measure(0, 0)
qc.draw('mpl')

# %%
result = execute(qc, backend = nativeSim, shots = 1024).result()
plot_histogram(result.get_counts(qc))

# %% [markdown]
# ## Quick Exercise 2

# %%
from qiskit_textbook.widgets import plot_bloch_vector_spherical
coords = [pi/2,0,1]
plot_bloch_vector_spherical(coords)

# %% [markdown]
# ### 1. The vector |0⟩

# %%
coordinates1 = [0, 0, 1]
plot_bloch_vector_spherical(coordinates1)

# %% [markdown]
# ### 2. The vector |1⟩

# %%
coordinates2 = [pi, 0, 1]
plot_bloch_vector_spherical(coordinates2)

# %% [markdown]
# ### 3. The vector 1√2(|0⟩ + |1⟩)

# %%
coordinates3 = [pi/2, 0, 1]
plot_bloch_vector_spherical(coordinates3)

# %% [markdown]
# ### 4. The vector 1√2(|0⟩ - i|1⟩)

# %%
coordinates4 = [3 * pi/4, pi/2, 1]
plot_bloch_vector_spherical(coordinates4)

# %% [markdown]
# ### 5. The vector $$ \frac{1}{\sqrt{2}} ~~\begin{bmatrix} i \\ 1  \end{bmatrix} $$

# %%
coordinates5 = [pi / 4, 3 * pi / 2, 1]
plot_bloch_vector_spherical(coordinates5)
